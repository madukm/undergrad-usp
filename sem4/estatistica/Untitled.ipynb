# %%
import pandas as pd
data = pd.read_csv("Titanic.csv")

# %%
print(data)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             1            1         0       3
# 1             2            2         1       1
# 2             3            3         1       3
# 3             4            4         1       1
# 4             5            5         0       3
# ..          ...          ...       ...     ...
# 709         886          886         0       3
# 710         887          887         0       2
# 711         888          888         1       1
# 712         890          890         1       1
# 713         891          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
data.loc

# %%
amostra = data.loc[data['PassengerId'] == 6]
amostra = data.loc[((data['PassengerId']-6)%4 == 0)]

# %%
amostra
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             2            2         1       1
# 8            10           10         1       2
# 12           14           14         0       3
# 18           22           22         1       2
# 22           26           26         1       3
# ..          ...          ...       ...     ...
# 698         874          874         0       3
# 702         878          878         0       3
# 705         882          882         0       3
# 709         886          886         0       3
# 712         890          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 8                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 12                         Andersson, Mr. Anders Johan    male  39.0      1
# 18                               Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
survived = amostra.loc[amostra['Survived'] == 1]

# %%
survived
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             2            2         1       1
# 8            10           10         1       2
# 18           22           22         1       2
# 22           26           26         1       3
# 39           54           54         1       2
# ..          ...          ...       ...     ...
# 681         854          854         1       1
# 685         858          858         1       1
# 691         866          866         1       2
# 694         870          870         1       3
# 712         890          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 8                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 18                               Beesley, Mr. Lawrence    male  34.0      0
# 22   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...
